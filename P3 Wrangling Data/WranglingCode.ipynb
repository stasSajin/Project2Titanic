# %% [markdown]
# <h1 align="center">Exploring Sacramento, California, with MongoDB</h1>
# <h3 align="center">Author: Stanislav Sajin</h3>

# %% [markdown]
# ## General Summary
# This document aims to wrangle OpenStreetMap data for the city of Sacramento, California. I chose this region because I currently reside here. This is not the report used for the project. For the report, please reffer to the file Report.pdf.
#
#     - Parse the data for tag types and tag counts
#     - Examine the validity of the data by looking at the tag keys within the XML file
#     - Audit the data, which will involve the following:
#         * Correct Street Name Typos (e.g. Placez to Plaza)
#         * Removal of data with invalid keys, such as a nonsensical street names (e.g., 9311, 9322).
#         * Normalization of abreviations (e.g., "St.", "St", "str", "Street" are changed into "Street")
#         * Normalization of the postal code;
#           -The zip needs to be between 94000-96000 (which corresponds more closely to Sacramento region and areas around it)
#           -The zip can either be a 5 digit code or a five digit code folloed by 4 digits (e.g., 95832-1447)
#           -The zip should not have non-digit strings.
#     -Problems encountered
#     -Exploring data with MongoDB

# %% [markdown]
# ### Area Image

# %% [markdown]
# <div style="text-align:center"><img src ="Sacramento.jpg" /></div>

# %% [markdown]
# ### Libraries

# %%
##Import all the libraries that will be used in this document
import pymongo
import os

# %% [markdown]
# ### Data Source Information
# I downloaded the data from https://mapzen.com/data/metro-extracts/.
#
# The OSM XML file can be downloaded here: https://s3.amazonaws.com/metro-extracts.mapzen.com/sacramento_california.osm.bz2

# %% [markdown]
# ### Data File Size Information
# I will be using getsize from os to measure the size of the uncompressed XML file. Since the file size given to me will be in bytes, I will divide the output by 1,000,000 to get the file size in MB

# %%
sizeXML=os.path.getsize('sacramento_california.osm')/1000000
sizeJSON=os.path.getsize('sacramento_california.osm.json')/1000000
print "The XML file size is "+str(sizeXML)+" MB"
print "The JSON file size is "+str(sizeJSON)+" MB"
# Out:
# The XML file size is 231 MB
# The JSON file size is 459 MB

# %% [markdown]
# ### Parse the data for tag types and tag counts
# The following code chunk will run the code inside mapparser.py and will return a dictionary with the type of tags found in the XML file and the counts for each tag.

# %%
# %run mapparser.py
# Out:
# defaultdict(<type 'int'>, {'node': 1028855, 'nd': 1180056, 'bounds': 1, 'member': 5565, 'tag': 757656, 'relation': 831, 'way': 100410, 'osm': 1})

# %% [markdown]
# In the code below I will run the tags.py and check the value of the keys in each tag to check for invalid keys.

# %%
# %run tags.py
# Out:
# <Element 'tag' at 0xa3ec860>
# Segment #
# <Element 'tag' at 0xa3ec128>
# Elevation, end
# <Element 'tag' at 0xa3ec400>
# Elevation, start
# <Element 'tag' at 0xa3ecc50>
# Elevation, maximum
# <Element 'tag' at 0xa3ec748>
# Elevation, minimum
# <Element 'tag' at 0xa3fd128>
# Segment #
# <Element 'tag' at 0xa3fd160>
# Elevation, end
# <Element 'tag' at 0xa44f0b8>
# Elevation, start
# <Element 'tag' at 0xa44f128>
# Elevation, maximum
# <Element 'tag' at 0xa44f198>
# Elevation, minimum
# <Element 'tag' at 0xa3f2518>
# Segment #
# <Element 'tag' at 0xa3f22b0>
# Elevation, end
# <Element 'tag' at 0xa3f2cc0>
# Elevation, start
# <Element 'tag' at 0xa3f2a58>
# Elevation, maximum
# <Element 'tag' at 0xa3f2390>
# Elevation, minimum
# <Element 'tag' at 0x3be99d68>
# gost_7.67-2003
# {'lower': 305683, 'lower_colon': 442468, 'other': 9489, 'problemchars': 16}

# %% [markdown]
# We have several keys with problem characters (16) that will be removed later when creating the structure of the json file. Next, I will lok at how many users we have contributed to our data.

# %%
# %run users.py
# Out:
# set(['100222',
#      '1007528',
#      '101372',
#      '101433',
#      '1015635',
#      '1016290',
#      '102870',
#      '102899',
#      '103253',
#      '103273',
#      '10353',
#      '103574',
#      '104519',
#      '104962',
#      '1051550',
#      '105462',
#      '1058666',
#      '1067273',
#      '107257',
#      '107566',
#      '10786',
#      '108149',
#      '1087647',
#      '108775',
#      '109362',
#      '109808',
#      '1098648',
#      '11006',
#      '110126',
#      '110263',
#      '1102790',
#      '11121',
#      '11126',
#      '11154',
#      '112254',
#      '1125908',
#      '113518',
#      '1136962',
#      '1149057',
#      '115064',
#      '1151679',
#      '1151882',
#      '11547',
#      '1155756',
#      '115592',
#      '115918',
#      '1161559',
#      '1164',
#      '1168707',
#      '1168909',
#      '1169950',
#      '1179821',
#      '118021',
#      '1195028',
#      '1195114',
#      '1196285',
#      '1198074',
#      '1198360',
#      '119881',
#      '120153',
#      '1204',
#      '1208453',
#      '121241',
#      '1214027',
#      '1215176',
#      '1215947',
#      '1219875',
#      '1224149',
#      '1227175',
#      '122748',
#      '1231449',
#      '123633',
#      '1240849',
#      '1241595',
#      '12434',
#      '1246157',
#      '1247041',
#      '1247193',
#      '1247484',
#      '1247645',
#      '1248925',
#      '1249130',
#      '1249205',
#      '125259',
#      '125339',
#      '125832',
#      '1260280',
#      '12667',
#      '12671',
#      '128017',
#      '1281559',
#      '1282393',
#      '128281',
#      '1288516',
#      '1291871',
#      '1292031',
#      '1295',
#      '130065',
#      '130122',
#      '130472',
#      '1306',
#      '131059',
#      '13203',
#      '1329572',
#      '1330847',
#      '133272',
#      '1337',
#      '134111',
#      '134112',
#      '1346935',
#      '135163',
#      '135329',
#      '1355899',
#      '1364517',
#      '1367770',
#      '1371102',
#      '1376118',
#      '1378814',
#      '13832',
#      '1385141',
#      '1385387',
#      '13861',
#      '1386271',
#      '1388075',
#      '1393642',
#      '139856',
#      '139879',
#      '139957',
#      '140038',
#      '1406438',
#      '1408522',
#      '1418137',
#      '1420318',
#      '1421843',
#      '142205',
#      '1424866',
#      '1425752',
#      '1425988',
#      '1426031',
#      '1426145',
#      '1426296',
#      '14293',
#      '1430450',
#      '1431737',
#      '143266',
#      '143523',
#      '1437096',
#      '1437965',
#      '1443840',
#      '145231',
#      '146549',
#      '147510',
#      '14850',
#      '1486839',
#      '1490939',
#      '149097',
#      '1492883',
#      '1494110',
#      '149876',
#      '150692',
#      '1507773',
#      '151372',
#      '15188',
#      '152074',
#      '152289',
#      '1535212',
#      '1536312',
#      '153669',
#      '1539155',
#      '1543113',
#      '154484',
#      '155187',
#      '15565',
#      '156109',
#      '158290',
#      '158709',
#      '1601196',
#      '160138',
#      '160148',
#      '161029',
#      '1611',
#      '1614521',
#      '161619',
#      '1617449',
#      '1624486',
#      '1624654',
#      '16315',
#      '163973',
#      '1649645',
#      '165',
#      '165061',
#      '1651798',
#      '1657',
#      '1660455',
#      '166129',
#      '166593',
#      '167009',
#      '167616',
#      '1679',
#      '1679807',
#      '1680214',
#      '168201',
#      '169004',
#      '1694420',
#      '1694880',
#      '170106',
#      '1702413',
#      '1706867',
#      '1708763',
#      '171055',
#      '1720076',
#      '172061',
#      '1721122',
#      '1721804',
#      '17292',
#      '1729291',
#      '1732161',
#      '1736354',
#      '1736524',
#      '173918',
#      '1749482',
#      '1750656',
#      '1751737',
#      '1754185',
#      '1760259',
#      '1762578',
#      '1764556',
#      '1773954',
#      '1775803',
#      '1777382',
#      '1778799',
#      '1781077',
#      '178114',
#      '178186',
#      '1782891',
#      '1782960',
#      '1783785',
#      '1784061',
#      '178626',
#      '1787830',
#      '178785',
#      '1790941',
#      '179581',
#      '179778',
#      '1798618',
#      '1802220',
#      '180455',
#      '1807586',
#      '181135',
#      '181166',
#      '1813267',
#      '1817244',
#      '1819',
#      '1823778',
#      '1826052',
#      '1827222',
#      '1827375',
#      '182796',
#      '1828723',
#      '1828725',
#      '1828748',
#      '1828779',
#      '1829683',
#      '1832883',
#      '183737',
#      '1839337',
#      '1842197',
#      '1843039',
#      '1846168',
#      '18462',
#      '1850404',
#      '1850735',
#      '1851026',
#      '1851521',
#      '1856919',
#      '1857094',
#      '1860612',
#      '1862910',
#      '1865279',
#      '186583',
#      '1868732',
#      '1869781',
#      '1870699',
#      '1870787',
#      '18776',
#      '187788',
#      '187839',
#      '1883376',
#      '188349',
#      '1883981',
#      '1884809',
#      '1886699',
#      '1886724',
#      '1887355',
#      '1887977',
#      '1890522',
#      '1892838',
#      '1893633',
#      '1901687',
#      '190493',
#      '1905782',
#      '1906062',
#      '190626',
#      '190869',
#      '1910589',
#      '1911765',
#      '1911822',
#      '1916593',
#      '191991',
#      '1921145',
#      '1922666',
#      '1928759',
#      '1938683',
#      '194231',
#      '19532',
#      '1957444',
#      '1959788',
#      '1960879',
#      '1960922',
#      '19612',
#      '1962459',
#      '1963215',
#      '1963515',
#      '1964253',
#      '196490',
#      '1966132',
#      '1968356',
#      '1971832',
#      '1981715',
#      '198742',
#      '1996396',
#      '1997448',
#      '1997916',
#      '1998099',
#      '1998252',
#      '199837',
#      '199963',
#      '2008037',
#      '200922',
#      '2010493',
#      '201149',
#      '2012449',
#      '201359',
#      '2015224',
#      '2016919',
#      '2021479',
#      '2021998',
#      '202256',
#      '2025408',
#      '2025547',
#      '202615',
#      '2028552',
#      '2032478',
#      '203700',
#      '2037901',
#      '2042390',
#      '2046535',
#      '2052948',
#      '2053369',
#      '2054683',
#      '205523',
#      '205524',
#      '2055526',
#      '2057966',
#      '20587',
#      '2065004',
#      '2066555',
#      '2070923',
#      '207581',
#      '207745',
#      '2087539',
#      '2089286',
#      '2090047',
#      '2090100',
#      '209668',
#      '2098',
#      '2099035',
#      '210115',
#      '21063',
#      '2110392',
#      '211300',
#      '2115228',
#      '2115749',
#      '2117558',
#      '212111',
#      '2121275',
#      '21323',
#      '213831',
#      '214671',
#      '2147',
#      '214758',
#      '215706',
#      '2157877',
#      '216260',
#      '217070',
#      '2174031',
#      '2175789',
#      '217828',
#      '2178325',
#      '2186370',
#      '2193331',
#      '219338',
#      '220320',
#      '2207528',
#      '221306',
#      '2219338',
#      '2222522',
#      '2224829',
#      '2226712',
#      '2229897',
#      '2231',
#      '223133',
#      '22347',
#      '2234934',
#      '2235480',
#      '2237984',
#      '224440',
#      '224610',
#      '2252891',
#      '2253816',
#      '2255038',
#      '2256726',
#      '2257257',
#      '2257313',
#      '2266634',
#      '227393',
#      '2274',
#      '2277040',
#      '2281061',
#      '2283782',
#      '229',
#      '2298146',
#      '231477',
#      '2318',
#      '232126',
#      '2323512',
#      '232386',
#      '2327845',
#      '233042',
#      '233248',
#      '23351',
#      '2338614',
#      '2339717',
#      '2357880',
#      '236172',
#      '2362216',
#      '236361',
#      '236412',
#      '2369506',
#      '2369643',
#      '2369667',
#      '2369673',
#      '2369675',
#      '2369676',
#      '2369679',
#      '2369684',
#      '2370233',
#      '237335',
#      '2376998',
#      '2377377',
#      '2380336',
#      '2381404',
#      '238584',
#      '2390275',
#      '239035',
#      '2391307',
#      '239432',
#      '239998',
#      '2406578',
#      '24119',
#      '2412184',
#      '2415107',
#      '242352',
#      '242798',
#      '243003',
#      '243490',
#      '243989',
#      '2441939',
#      '24440',
#      '24452',
#      '2454788',
#      '2475974',
#      '2475999',
#      '2482304',
#      '2483961',
#      '2488',
#      '2497300',
#      '2502134',
#      '2504552',
#      '250487',
#      '2506140',
#      '2510626',
#      '2511706',
#      '25120',
#      '2512300',
#      '251543',
#      '252456',
#      '2527838',
#      '252811',
#      '2533093',
#      '2542073',
#      '2546103',
#      '2548768',
#      '25510',
#      '2554698',
#      '2566430',
#      '25867',
#      '2590839',
#      '2593828',
#      '260682',
#      '262151',
#      '2625348',
#      '26299',
#      '263449',
#      '2644101',
#      '2644389',
#      '2655992',
#      '2675',
#      '2676553',
#      '2706893',
#      '2711928',
#      '2733281',
#      '2734322',
#      '2734807',
#      '27408',
#      '2746981',
#      '2748195',
#      '2758',
#      '2770719',
#      '2778924',
#      '2782143',
#      '28024',
#      '280354',
#      '28054',
#      '2806850',
#      '2810217',
#      '281267',
#      '2813997',
#      '28145',
#      '2815098',
#      '2823295',
#      '28269',
#      '2829263',
#      '2835928',
#      '28378',
#      '2847988',
#      '285369',
#      '28559',
#      '2856319',
#      '2859402',
#      '28602',
#      '286075',
#      '286452',
#      '2872644',
#      '2874110',
#      '2874662',
#      '2877150',
#      '28775',
#      '28783',
#      '2890328',
#      '28923',
#      '2892531',
#      '2900640',
#      '2900837',
#      '290112',
#      '2905914',
#      '290680',
#      '29084',
#      '2910446',
#      '2912023',
#      '292007',
#      '292081',
#      '292665',
#      '29272',
#      '2927409',
#      '2929338',
#      '2930773',
#      '2931305',
#      '2931764',
#      '29320',
#      '293774',
#      '2959379',
#      '296575',
#      '296803',
#      '296869',
#      '296912',
#      '297482',
#      '298394',
#      '2990401',
#      '3007580',
#      '30077',
#      '3036006',
#      '304179',
#      '3048633',
#      '305985',
#      '306096',
#      '3078393',
#      '308649',
#      '3088631',
#      '3092571',
#      '309382',
#      '3099631',
#      '310589',
#      '311318',
#      '31138',
#      '31231',
#      '3127',
#      '31349',
#      '3142868',
#      '314357',
#      '3151684',
#      '3158',
#      '3161120',
#      '3164012',
#      '316567',
#      '31795',
#      '318696',
#      '318897',
#      '3208315',
#      '321862',
#      '322034',
#      '322785',
#      '3231815',
#      '323789',
#      '32529',
#      '3272286',
#      '32751',
#      '327578',
#      '3277198',
#      '3280829',
#      '32952',
#      '3301319',
#      '3305066',
#      '330630',
#      '330773',
#      '331938',
#      '3330791',
#      '3363',
#      '336354',
#      '336659',
#      '33708',
#      '3374158',
#      '3375387',
#      '33757',
#      '3381552',
#      '3382761',
#      '339064',
#      '3391456',
#      '3392',
#      '3394652',
#      '339488',
#      '3400077',
#      '3400980',
#      '3406980',
#      '3426325',
#      '34305',
#      '343107',
#      '3432400',
#      '3464732',
#      '3482553',
#      '351324',
#      '3516',
#      '351993',
#      '3528112',
#      '353053',
#      '3537983',
#      '355242',
#      '355617',
#      '3560',
#      '3569951',
#      '3582',
#      '35935',
#      '36038',
#      '360392',
#      '36121',
#      '3618840',
#      '364739',
#      '36489',
#      '368215',
#      '368493',
#      '3686356',
#      '3686832',
#      '3696203',
#      '3700',
#      '3705739',
#      '371121',
#      '371387',
#      '37223',
#      '373434',
#      '37392',
#      '37548',
#      '3762',
#      '37636',
#      '377053',
#      '379381',
#      '381909',
#      '382406',
#      '38352',
#      '383843',
#      '384084',
#      '38410',
#      '384119',
#      '38487',
#      '38544',
#      '388774',
#      '393509',
#      '3937',
#      '39457',
#      '39504',
#      '395071',
#      '395416',
#      '39569',
#      '396743',
#      '39688',
#      '39717',
#      '39774',
#      '397946',
#      '398086',
#      '398300',
#      '39878',
#      '399543',
#      '401490',
#      '402563',
#      '40257',
#      '402624',
#      '402700',
#      '404532',
#      '4054',
#      '408202',
#      '409567',
#      '409569',
#      '409570',
#      '40964',
#      '411244',
#      '41159',
#      '413047',
#      '413068',
#      '413282',
#      '413501',
#      '416346',
#      '41722',
#      '42123',
#      '421504',
#      '42191',
#      '422063',
#      '42208',
#      '42429',
#      '425300',
#      '427658',
#      '436419',
#      '437598',
#      '440812',
#      '44200',
#      '444469',
#      '445142',
#      '445671',
#      '44659',
#      '4473',
#      '447903',
#      '448087',
#      '449038',
#      '449041',
#      '449045',
#      '449048',
#      '449049',
#      '449058',
#      '449071',
#      '449072',
#      '449074',
#      '449076',
#      '449077',
#      '449079',
#      '44938',
#      '4499',
#      '45027',
#      '451048',
#      '451600',
#      '451693',
#      '45399',
#      '459441',
#      '459925',
#      '461103',
#      '461945',
#      '462373',
#      '46239',
#      '463102',
#      '463667',
#      '46482',
#      '4660',
#      '467703',
#      '46789',
#      '4685',
#      '4697',
#      '470034',
#      '47090',
#      '471770',
#      '4732',
#      '473445',
#      '473471',
#      '474183',
#      '475877',
#      '476589',
#      '47769',
#      '47888',
#      '479256',
#      '481934',
#      '482916',
#      '488840',
#      '49031',
#      '492311',
#      '49351',
#      '493595',
#      '4951',
#      '496201',
#      '500006',
#      '500450',
#      '500756',
#      '501715',
#      '502142',
#      '502525',
#      '504224',
#      '505284',
#      '505740',
#      '50624',
#      '507893',
#      '508',
#      '509556',
#      '509902',
#      '51045',
#      '510834',
#      '510836',
#      '510976',
#      '510980',
#      '5121',
#      '513142',
#      '5164',
#      '51675',
#      '51901',
#      '519610',
#      '51991',
#      '52201',
#      '522320',
#      '527116',
#      '527588',
#      '52797',
#      '529108',
#      '52921',
#      '53073',
#      '53127',
#      '531915',
#      '532783',
#      '533465',
#      '5359',
#      '53936',
#      '53964',
#      '5409',
#      '54663',
#      '550560',
#      '554234',
#      '55693',
#      '55774',
#      '558185',
#      '558778',
#      '559890',
#      '560680',
#      '5616',
#      '561854',
#      '561858',
#      '561868',
#      '561899',
#      '561904',
#      '561926',
#      '561927',
#      '56410',
#      '564222',
#      '56597',
#      '567792',
#      '56798',
#      '568749',
#      '5713',
#      '571410',
#      '57158',
#      '574356',
#      '5748',
#      '575547',
#      '57882',
#      '581419',
#      '583857',
#      '583870',
#      '586964',
#      '587281',
#      '589596',
#      '589645',
#      '5926',
#      '592819',
#      '593205',
#      '594525',
#      '595221',
#      '596047',
#      '596295',
#      '5974',
#      '597941',
#      '599013',
#      '599133',
#      '599436',
#      '601230',
#      '60137',
#      '602351',
#      '610770',
#      '61216',
#      '612472',
#      '615059',
#      '6157',
#      '615739',
#      '615826',
#      '616573',
#      '616774',
#      '618035',
#      '618377',
#      '61942',
#      '620183',
#      '621111',
#      '622455',
#      '622490',
#      '625328',
#      '628788',
#      '63107',
#      '632355',
#      '63375',
#      '63726',
#      '638697',
#      '638799',
#      '6389',
#      '63936',
#      '63969',
#      '642044',
#      '643201',
#      '645457',
#      '645538',
#      '646734',
#      '654164',
#      '654326',
#      '654563',
#      '659911',
#      '663025',
#      '665694',
#      '6669',
#      '671437',
#      '672019',
#      '672028',
#      '672039',
#      '672049',
#      '672058',
#      '67236',
#      '673456',
#      '674039',
#      '67862',
#      '67896',
#      '67931',
#      '682',
#      '684204',
#      '685346',
#      '68581',
#      '68982',
#      '691463',
#      '691931',
#      '69319',
#      '693228',
#      '693948',
#      '6975',
#      '69791',
#      '69853',
#      '701297',
#      '702133',
#      '703517',
#      '70696',
#      '709618',
#      '712392',
#      '713822',
#      '713846',
#      '714898',
#      '715150',
#      '715371',
#      '71555',
#      '7168',
#      '718617',
#      '718897',
#      '7203',
#      '720759',
#      '722137',
#      '72235',
#      '72250',
#      '725620',
#      '7275',
#      '730573',
#      '731064',
#      '734',
#      '735',
#      '74275',
#      '745580',
#      '74570',
#      '745841',
#      '74897',
#      '74900',
#      '75317',
#      '76002',
#      '76269',
#      '775666',
#      '78269',
#      '78656',
#      '78918',
#      '79401',
#      '795290',
#      '79593',
#      '80046',
#      '803503',
#      '81024',
#      '811230',
#      '81285',
#      '817782',
#      '82271',
#      '822818',
#      '82317',
#      '82783',
#      '82877',
#      '8296',
#      '8339',
#      '837066',
#      '837425',
#      '84054',
#      '84263',
#      '8464',
#      '846566',
#      '84681',
#      '84796',
#      '85218',
#      '855535',
#      '85673',
#      '85721',
#      '8609',
#      '863669',
#      '86504',
#      '86565',
#      '866796',
#      '86806',
#      '8703',
#      '87100',
#      '87276',
#      '87286',
#      '873940',
#      '8764',
#      '881429',
#      '88164',
#      '88337',
#      '88448',
#      '8909',
#      '893327',
#      '89943',
#      '90019',
#      '90439',
#      '9065',
#      '909670',
#      '911926',
#      '91225',
#      '912433',
#      '91499',
#      '9176',
#      '92274',
#      '92286',
#      '92387',
#      '933797',
#      '93788',
#      '941449',
#      '94578',
#      '950776',
#      '95132',
#      '95702',
#      '96069',
#      '967832',
#      '97356',
#      '97529',
#      '9781',
#      '98369',
#      '98682',
#      '988092',
#      '990535',
#      '996997'])

# %% [markdown]
# The next python script aims to run the audit and the data. The script will clean up the street names a bit and also remove an incorrect zipcode.

# %%
# %run audit.py
# Out:
# defaultdict(<type 'int'>, {'96816': 5, '95819-6138': 1, 'CA 95747': 2, 'CA 95834': 2, 'CA 95833': 1, 'CA 95832': 1, 'CA 95626': 1, '95609-0579': 1, 'CA 95819': 1, 'CA 95628': 1, 'CA 95602': 1, '96516': 2, 'CA 95648': 1, '95826-2625': 1, '95819-6024': 1, 'CA 95683': 1, '85834': 1, 'CA 95829': 1, 'CA 95826': 1, 'CA 95827': 1, 'CA 95822': 1, '95832-1447': 2, '98584': 1, 'CA 95616': 2, '95616-5270': 3, 'CA 95655': 1, u'CA 95650 \u200e': 1, 'CA 95659': 1})
# {'1': set(['California Highway 16, House No. 1']),
#  '102': set(['County Road 102']),
#  '110,': set(['Promenade Circle #110,']),
#  '18C': set(['County Road 18C']),
#  '193': set(['Highway 193', 'Sw Cnr Sierra College Blvd / Sr 193']),
#  '310': set(['Greenback Lane, Suite 310']),
#  '5': set(['2nd St/Rte 5']),
#  '50': set(['3rd St / Rte 50']),
#  '5259': set(['PO Box 5259']),
#  '9311': set(['9311']),
#  '9321': set(['9321']),
#  '95628-7416': set(['Fair Oaks Boulevard, Fair Oaks, CA 95628-7416']),
#  '95683': set(['Pera Dr at Escuela Drive, Rancho Murieta, Ca 95683']),
#  '99': set(['13th Ave Rte 99', '47th Avenue / Rte 99', 'County Road 99']),
#  'Alley': set(['Del Paso Boulevard el Monte Avenue Alley']),
#  'Arena': set(['Arena']),
#  'Auburn': set(['Auburn']),
#  'Ave': set(['Auburn Ave',
#              'Central Ave',
#              'Manzanita Ave',
#              'Ne Quad Enterprise Dr / I-80 Ic @ Capitol Ave',
#              'Norris Ave',
#              'Pasadena Ave']),
#  'Ave.': set(['Auburn Ave.', 'Norris Ave.', 'Orange Grove Ave.', 'Watt Ave.']),
#  'Bikeway': set(['Sprockett Bikeway']),
#  'Blvd': set(['6010 Folsom Blvd',
#               '9660 Stockton Blvd',
#               'Arena Blvd',
#               'Auburn Blvd',
#               'Folsom Blvd',
#               'Franklin Blvd',
#               'Galleria Blvd',
#               'Mace Blvd',
#               'N. Market Blvd',
#               'Northgate Blvd',
#               'Russell Blvd',
#               'Stockton Blvd']),
#  'Blvd.': set(['Arena Blvd.',
#                'Auburn Blvd.',
#                'Fair Oaks Blvd.',
#                'Northgate Blvd.']),
#  'Boulevar': set(['Lake Washington Boulevar']),
#  'Bridlewood': set(['Bridlewood']),
#  'Broadway': set(['Broadway']),
#  'Buljan': set(['Douglas Blvd @ Buljan']),
#  'CT': set(['Isles CT']),
#  'Center': set(['Cal Center', 'Ne Side Next To Aquatic Center']),
#  'Circle': set(['Abilene Circle',
#                 'Anvil Circle',
#                 'Bottlebrush Circle',
#                 'Brennen Circle',
#                 'Brick Mason Circle',
#                 'Brookfield Circle',
#                 'Brookline Circle',
#                 'Caldarella Circle',
#                 'California Circle',
#                 'Camp Whitney Circle',
#                 'Campfire Circle',
#                 'Clearbrook Circle',
#                 'Corona Circle',
#                 'Cottage Circle',
#                 'Creekstone Circle',
#                 'Daffodil Circle',
#                 'Deerwood Circle',
#                 'Dornie Circle',
#                 'Dunsley Circle',
#                 'Evergreen Circle',
#                 'Everley Circle',
#                 'Ferndale Circle',
#                 'Flocchini Circle',
#                 'Foxcroft Circle',
#                 'Freeman Circle',
#                 'Glastonbury Circle',
#                 'Gooseberry Circle',
#                 'Grasmere Circle',
#                 'Grouse Run Circle',
#                 'Half Moon Bay Circle',
#                 'Hartland Circle',
#                 'Hilmerton Circle',
#                 'Huckleberry Circle',
#                 'Hughes Circle',
#                 'Imran Woods Circle',
#                 'Kathy Circle',
#                 'Las Brisas Circle',
#                 'Manza Circle',
#                 'McNair Circle',
#                 'Meadowlark Circle',
#                 'Montclair Circle',
#                 'Mosswood Circle',
#                 'Orchard Park Circle',
#                 'Park Circle',
#                 'Pasatiempo Circle',
#                 'Pitzer Circle',
#                 'Racetrack Circle',
#                 'Ridgemere Circle',
#                 'Rockrose Circle',
#                 'Rogue River Circle',
#                 'Saint Basil Circle',
#                 'San Carlos Circle',
#                 'San Diego Circle',
#                 'San Lucas Circle',
#                 'Santiago Circle',
#                 'Snapdragon Circle',
#                 'Snowberry Circle',
#                 'Solano Park Circle',
#                 'Sorrell Circle',
#                 'Stageline Circle',
#                 'Staxton Circle',
#                 'Sterling Circle',
#                 'Terracina Circle',
#                 'Tradewinds Circle',
#                 'Welton Circle',
#                 'Westwood Circle',
#                 'Wighill Circle',
#                 'Wild Plains Circle',
#                 'Windward Circle']),
#  'Cnr': set(['@ Sunrise Blvd Nw Cnr']),
#  'DR': set(['DESTINY DR', 'HIGHLAND POINTE DR']),
#  'Dr': set(['Banfield Dr', 'Olive Dr', 'State University Dr']),
#  'Dr.': set(['College Oak Dr.', 'Fairway Dr.', 'Zinfandel Dr.']),
#  'E': set(['Tribute Road, Suite E']),
#  'Eureka': set(['Taylor @ Atlantic / Eureka']),
#  'Expressway': set(['Alta Arden Expressway']),
#  'Extension': set(['Old Davis Road Extension']),
#  'Floor': set(['11th Street, Fifth Floor']),
#  'Highway': set(['Grass Valley Highway', 'Lincoln Newcastle Highway']),
#  'Hwy': set(['1050 Grass Valley Hwy']),
#  'I/C': set(['Sr 193 @ Lincoln / Ophir I/C']),
#  'Ic': set(['Sw Quad Enterprise Dr / I-80 Ic']),
#  'Industrial': set(['Industrial']),
#  'Ingoglia': set(['Via Ingoglia']),
#  'Int': set(['E Side Newcastle Rd Int',
#              'Indian Hills Road & Newcastle Rd Int',
#              'Ne Side Merrychase Drive Int',
#              'S Side Sierra College Blvd Int',
#              'Se Cnr  Sheldon Rd Int']),
#  'Latrobe': set(['S Of Us 50, E Side Of Latrobe']),
#  'Loop': set(['Appersett Loop',
#               'Aurora Loop',
#               'Benton Loop',
#               'Bickleigh Loop',
#               'Devonport Loop',
#               'Ellesmere Loop',
#               'Eskaton Loop',
#               'Land End Loop',
#               'Penstone Loop',
#               'Pipestone Loop',
#               'Rainhill Loop',
#               'Secret Lake Loop',
#               'Tapaderas Loop',
#               'Vignolia Loop',
#               'Warm Hearth Loop',
#               'Whispering Creek Loop']),
#  'Mall': set(['Capitol Mall', 'Physical Sciences Mall']),
#  'Manzanita': set(['Manzanita']),
#  'Northgate': set(['Northgate']),
#  'Orlando': set(['Missionary Church Cirby & Orlando']),
#  'PKWY': set(['Southport P PKWY']),
#  'Park': set(['College Park', 'Russell Park']),
#  'Pkwy': set(['Oak Ave Pkwy']),
#  'PlaceZ': set(['Elkhorn PlaceZ', 'Town Center PlaceZ']),
#  'Plaza': set(['Sierra Gate Plaza', 'Town Center Plaza']),
#  'Porthill': set(['Porthill']),
#  'Quad': set(['North Quad']),
#  'Raod': set(['Orchard Raod']),
#  'Rd': set(['Atwood Rd',
#             'Blue Ravine Rd',
#             'Bruceville Rd',
#             'Florin Rd',
#             'Jackson Rd',
#             'Lincoln Way @ Bowman Rd',
#             'S. Power Inn Rd']),
#  'Riata': set(['Via Riata']),
#  'Ridge': set(['Meadowlark Way & Maidu Dr Near Rocky Ridge']),
#  'Road)': set(['Penryn Rd Int Nw Of I-80 On Frontage Road (Boyington Road)']),
#  'Roseville': set(['East Roseville']),
#  'ST': set(['L ST']),
#  'Side': set(['Elkhorn Blvd Sw Side',
#               'Horseshoe Bar Rd Int S Side',
#               'Int Bell Rd & Bowman Rd Nw Side']),
#  'St': set(['Arthur St', 'E Bidwell St']),
#  'St.': set(['East Bidwell St.']),
#  'Stockton': set(['Geneva Pt Dr @ Stockton']),
#  'Stores': set(['Across Street From Factory Outlet Stores']),
#  'Terrace': set(['Messina Terrace', 'Serrano Terrace', 'Simon Terrace']),
#  'Uppr': set(['Freeport Blvd Uppr']),
#  'Verdera': set(['Catta Verdera']),
#  'Way': set(['Acton Way',
#              'Advantage Way',
#              'Alder Way',
#              'Amber Fields Way',
#              'Amber Waves Way',
#              'Amoruso Way',
#              'Apiary Way',
#              'Apple Way',
#              'Arden Way',
#              'Ashwood Way',
#              'Astaire Way',
#              'Aylesbury Way',
#              'Ballantrae Way',
#              'Barbrook Way',
#              'Barossa Way',
#              'Beatty Way',
#              'Becerra Way',
#              'Benstermere Way',
#              'Bethel Way',
#              'Betty Way',
#              'Big Brook Way',
#              'Big Creek Way',
#              'Big Tree Way',
#              'Blakesley Way',
#              'Blue Skies Way',
#              'Bogart Way',
#              'Bolton Way',
#              'Braddock Way',
#              'Bradford Way',
#              'Brannan Way',
#              'Brenda Way',
#              'Brent Mill Way',
#              'Broad Stripes Way',
#              'Brook Ridge Way',
#              'Burchard Way',
#              'Burrelton Way',
#              'Burwell Way',
#              'Business Park Way',
#              'Butterfield Way',
#              'Buxton Way',
#              'Callawassie Way',
#              'Calverhall Way',
#              'Camarena Way',
#              'Camborne Way',
#              'Camino Real Way',
#              'Canna Way',
#              'Cantamar Way',
#              'Canvasback Way',
#              'Cape Coral Way',
#              'Cargill Way',
#              'Carneilian Way',
#              'Carpenter Way',
#              'Castle Pines Way',
#              'Castle Rock Way',
#              'Cattledrive Way',
#              'Challenge Way',
#              'Chaparral Way',
#              'Cheval Way',
#              'Chignahuapan Way',
#              'Chuckwagon Way',
#              'Cirby Way',
#              'Cornhill Way',
#              'Cornwall Way',
#              'Courante Way',
#              'Courtney Way',
#              'Crawford Way',
#              'Creamery Way',
#              'Culverhill Way',
#              'Cummins Way',
#              'Dallen Way',
#              'Decker Way',
#              'Delano Way',
#              'Derby Way',
#              'Diego Way',
#              'Dressler Way',
#              'Dunford Way',
#              'Early Way',
#              'East Cliff Way',
#              'Edenbridge Way',
#              'Eldmire Way',
#              'Ensemble Way',
#              'Enterprise Way',
#              'Farrier Way',
#              'Flagstaff Way',
#              'Fontenay Way',
#              'Fort Collins Way',
#              'Franklin Way',
#              'Fuhrman Way',
#              'Garland Way',
#              'Gate Way',
#              'Gatwick Way',
#              'Glenmark Way',
#              'Glenwood Springs Way',
#              'Gold Mine Way',
#              'Goodstone Way',
#              'Granada Way',
#              'Grand Junction Way',
#              'Granite Way',
#              'Greenford Way',
#              'Greenhills Way',
#              'Grizzly Way',
#              'Grove Hill Way',
#              'Hanson Way',
#              'Havering Way',
#              'Hearthside Way',
#              'Heirloom Way',
#              'Helmsdale Way',
#              'Herzer Way',
#              'Hickory Way',
#              'Hightrail Way',
#              'Hovey Way',
#              'Howard Way',
#              'Hummingbird Way',
#              'Hurlston Way',
#              'Ice House Way',
#              'Ironwood Way',
#              'Jerome Way',
#              'Jimmy Way',
#              'Kenwood Way',
#              'Kinsella Way',
#              'Knapton Way',
#              'Lamar Way',
#              'Lansdowne Way',
#              'Lasso Way',
#              'Lathwell Way',
#              'Laurelwood Way',
#              'Legends Way',
#              'Leighton Way',
#              'Lemontree Way',
#              'Levison Way',
#              'Lincoln Way',
#              'Littleton Way',
#              'Lockhart Way',
#              'Lookout Pass Way',
#              'Lorimer Way',
#              'Lunardi Way',
#              'Maestro Way',
#              'Majestic Prince Way',
#              'Malachite Way',
#              'Mandeville Way',
#              'Manzanita Way',
#              'Mareca Way',
#              'Margaret Way',
#              'Marlee Way',
#              'McCloud Way',
#              'McRae Way',
#              'Mckinley Way',
#              'Mead Way',
#              'Mendota Way',
#              'Merced Way',
#              'Missile Way',
#              'Mist Hill Way',
#              'Morning Mist Way',
#              'Northbrook Way',
#              'Oak Trail Way',
#              'Oakmont Way',
#              'Opera Way',
#              'Orchard Way',
#              'Overton Way',
#              'Paradise Way',
#              'Parklake Way',
#              'Parkland Way',
#              'Parkminster Way',
#              'Parkside Way',
#              'Parkwood Way',
#              'Patagonia Way',
#              'Peacekeeper Way',
#              'Peoria Way',
#              'Petruchio Way',
#              'Pistachio Way',
#              'Placer Corporate Way',
#              'Point West Way',
#              'Prairie Grass Way',
#              'Ranchland Way',
#              'Rand Way',
#              'Ravenna Way',
#              'Recital Way',
#              'Redmire Way',
#              'Retreat Way',
#              'Rezzano Way',
#              'Robinson Way',
#              'Roxby Way',
#              'Rubicon Way',
#              'Rulander Way',
#              'Rundel Way',
#              'Saint Francis Way',
#              'Saint Julien Way',
#              'Saint julien Way',
#              'San Jose Way',
#              'San Lorenzo Way',
#              'Sandhurst Way',
#              'Sandringham Way',
#              'Sandwick Way',
#              'Scholar Way',
#              'Sculpin Way',
#              'Secret Ravine Way',
#              'Sellers Way',
#              'Serpa Way',
#              'Settlers Ridge Way',
#              'Shadowbrook Way',
#              'Sharifa Way',
#              'Sharon Way',
#              'Shasta Way',
#              'Shenencock Way',
#              'Shorthorn Way',
#              'Sonata Way',
#              'Sonora Pass Way',
#              'Southington Way',
#              'Spanish Bay Way',
#              'Spruce Way',
#              'Staghorn Way',
#              'Summerland Way',
#              'Tantara Way',
#              'Technology Way',
#              'Testarossa Way',
#              'Trimstone Way',
#              'Trinity Way',
#              'Tyler Way',
#              'Valleywood Way',
#              'Wabash Way',
#              'Wagon Trail Way',
#              'Wailea Way',
#              'Waterhouse Way',
#              'Weathervane Way',
#              'Welland Way',
#              'Wentworth Way',
#              'Westmeath Way',
#              'Wheelright Way',
#              'Whistlestop Way',
#              'Willard Way',
#              'Winding Creek Way',
#              'Winding Way',
#              'Wood Way',
#              'Woodfield Way',
#              'Woodgate Way',
#              'Wyman Way']),
#  'West': set(['Portage Bay West', 'Sunset Boulevard West']),
#  'Zollhaus': set(['Zollhaus']),
#  'street': set(['S street']),
#  'way': set(['san lorenzo way'])}
# Porthill => Porthill
# Manzanita => Manzanita
# Pera Dr at Escuela Drive, Rancho Murieta, Ca 95683 => Pera Drive At Escuela Drive Rancho Murieta Ca 95683
# @ Sunrise Blvd Nw Cnr => At Sunrise Boulevard Northwest Corner
# Catta Verdera => Catta Verdera
# 11th Street, Fifth Floor => 11th Street Fifth Floor
# Sunset Boulevard West => Sunset Boulevard West
# Portage Bay West => Portage Bay West
# East Bidwell St. => East Bidwell Street
# Greenback Lane, Suite 310 => Greenback Lane Suite 310
# Taylor @ Atlantic / Eureka => Taylor At Atlantic / Eureka
# Sw Cnr Sierra College Blvd / Sr 193 => Southwest Corner Sierra College Boulevard / Sr 193
# Highway 193 => Highway 193
# Blue Ravine Rd => Blue Ravine Road
# Atwood Rd => Atwood Road
# Lincoln Way @ Bowman Rd => Lincoln Way At Bowman Road
# Bruceville Rd => Bruceville Road
# Florin Rd => Florin Road
# Jackson Rd => Jackson Road
# S. Power Inn Rd => S Power Inn Road
# S street => S Street
# Recital Way => Recital Way
# Amber Waves Way => Amber Waves Way
# Advantage Way => Advantage Way
# McRae Way => Mcrae Way
# Jerome Way => Jerome Way
# Glenmark Way => Glenmark Way
# Hanson Way => Hanson Way
# Fort Collins Way => Fort Collins Way
# Sellers Way => Sellers Way
# San Jose Way => San Jose Way
# Saint Francis Way => Saint Francis Way
# Saint julien Way => Saint Julien Way
# Roxby Way => Roxby Way
# Hovey Way => Hovey Way
# Parkland Way => Parkland Way
# Kinsella Way => Kinsella Way
# Braddock Way => Braddock Way
# Sonata Way => Sonata Way
# Herzer Way => Herzer Way
# Parkwood Way => Parkwood Way
# Fontenay Way => Fontenay Way
# Courante Way => Courante Way
# Brook Ridge Way => Brook Ridge Way
# Northbrook Way => Northbrook Way
# Sandwick Way => Sandwick Way
# Alder Way => Alder Way
# Heirloom Way => Heirloom Way
# Hightrail Way => Hightrail Way
# McCloud Way => Mccloud Way
# Manzanita Way => Manzanita Way
# Becerra Way => Becerra Way
# Kenwood Way => Kenwood Way
# Sonora Pass Way => Sonora Pass Way
# Spanish Bay Way => Spanish Bay Way
# Burrelton Way => Burrelton Way
# Scholar Way => Scholar Way
# Prairie Grass Way => Prairie Grass Way
# Trinity Way => Trinity Way
# Knapton Way => Knapton Way
# Carneilian Way => Carneilian Way
# Helmsdale Way => Helmsdale Way
# Decker Way => Decker Way
# Secret Ravine Way => Secret Ravine Way
# Brent Mill Way => Brent Mill Way
# Delano Way => Delano Way
# Wabash Way => Wabash Way
# Hummingbird Way => Hummingbird Way
# Rundel Way => Rundel Way
# Placer Corporate Way => Placer Corporate Way
# Winding Creek Way => Winding Creek Way
# Overton Way => Overton Way
# Chignahuapan Way => Chignahuapan Way
# Marlee Way => Marlee Way
# Jimmy Way => Jimmy Way
# Grove Hill Way => Grove Hill Way
# Lamar Way => Lamar Way
# Valleywood Way => Valleywood Way
# Wailea Way => Wailea Way
# Big Tree Way => Big Tree Way
# Opera Way => Opera Way
# Waterhouse Way => Waterhouse Way
# Rubicon Way => Rubicon Way
# Redmire Way => Redmire Way
# Summerland Way => Summerland Way
# Burchard Way => Burchard Way
# Enterprise Way => Enterprise Way
# Shadowbrook Way => Shadowbrook Way
# Ensemble Way => Ensemble Way
# Weathervane Way => Weathervane Way
# Sharon Way => Sharon Way
# Glenwood Springs Way => Glenwood Springs Way
# Rand Way => Rand Way
# Malachite Way => Malachite Way
# Bradford Way => Bradford Way
# Ravenna Way => Ravenna Way
# Cornhill Way => Cornhill Way
# Apple Way => Apple Way
# Beatty Way => Beatty Way
# San Lorenzo Way => San Lorenzo Way
# Levison Way => Levison Way
# Mead Way => Mead Way
# Cape Coral Way => Cape Coral Way
# Lincoln Way => Lincoln Way
# Tyler Way => Tyler Way
# Camarena Way => Camarena Way
# Cantamar Way => Cantamar Way
# Bogart Way => Bogart Way
# Amoruso Way => Amoruso Way
# Oak Trail Way => Oak Trail Way
# Wagon Trail Way => Wagon Trail Way
# Leighton Way => Leighton Way
# Lathwell Way => Lathwell Way
# Rulander Way => Rulander Way
# Challenge Way => Challenge Way
# Dunford Way => Dunford Way
# Eldmire Way => Eldmire Way
# Lockhart Way => Lockhart Way
# Ranchland Way => Ranchland Way
# Farrier Way => Farrier Way
# Cargill Way => Cargill Way
# Sharifa Way => Sharifa Way
# Shorthorn Way => Shorthorn Way
# Parklake Way => Parklake Way
# Gate Way => Gate Way
# Brannan Way => Brannan Way
# Lookout Pass Way => Lookout Pass Way
# Wood Way => Wood Way
# Dressler Way => Dressler Way
# Garland Way => Garland Way
# Benstermere Way => Benstermere Way
# Barossa Way => Barossa Way
# Cattledrive Way => Cattledrive Way
# Gold Mine Way => Gold Mine Way
# Spruce Way => Spruce Way
# Callawassie Way => Callawassie Way
# Castle Pines Way => Castle Pines Way
# Granada Way => Granada Way
# Camino Real Way => Camino Real Way
# Cummins Way => Cummins Way
# Southington Way => Southington Way
# Sculpin Way => Sculpin Way
# Wentworth Way => Wentworth Way
# Cheval Way => Cheval Way
# East Cliff Way => East Cliff Way
# Staghorn Way => Staghorn Way
# Greenhills Way => Greenhills Way
# Shenencock Way => Shenencock Way
# Acton Way => Acton Way
# Robinson Way => Robinson Way
# Tantara Way => Tantara Way
# Maestro Way => Maestro Way
# Lasso Way => Lasso Way
# Parkside Way => Parkside Way
# Broad Stripes Way => Broad Stripes Way
# Peacekeeper Way => Peacekeeper Way
# Lemontree Way => Lemontree Way
# Retreat Way => Retreat Way
# Margaret Way => Margaret Way
# Settlers Ridge Way => Settlers Ridge Way
# Peoria Way => Peoria Way
# Winding Way => Winding Way
# Courtney Way => Courtney Way
# Ashwood Way => Ashwood Way
# Chaparral Way => Chaparral Way
# Patagonia Way => Patagonia Way
# Wheelright Way => Wheelright Way
# Lunardi Way => Lunardi Way
# Apiary Way => Apiary Way
# Business Park Way => Business Park Way
# Littleton Way => Littleton Way
# Mist Hill Way => Mist Hill Way
# Oakmont Way => Oakmont Way
# Goodstone Way => Goodstone Way
# Bethel Way => Bethel Way
# Canna Way => Canna Way
# Franklin Way => Franklin Way
# Hearthside Way => Hearthside Way
# Orchard Way => Orchard Way
# Willard Way => Willard Way
# Whistlestop Way => Whistlestop Way
# Petruchio Way => Petruchio Way
# Parkminster Way => Parkminster Way
# Trimstone Way => Trimstone Way
# Testarossa Way => Testarossa Way
# Big Creek Way => Big Creek Way
# Pistachio Way => Pistachio Way
# Mandeville Way => Mandeville Way
# Gatwick Way => Gatwick Way
# Greenford Way => Greenford Way
# Mckinley Way => Mckinley Way
# Havering Way => Havering Way
# Amber Fields Way => Amber Fields Way
# Saint Julien Way => Saint Julien Way
# Mendota Way => Mendota Way
# Arden Way => Arden Way
# Merced Way => Merced Way
# Aylesbury Way => Aylesbury Way
# Hickory Way => Hickory Way
# Granite Way => Granite Way
# Edenbridge Way => Edenbridge Way
# Laurelwood Way => Laurelwood Way
# Betty Way => Betty Way
# Legends Way => Legends Way
# Grizzly Way => Grizzly Way
# Chuckwagon Way => Chuckwagon Way
# Ironwood Way => Ironwood Way
# Lorimer Way => Lorimer Way
# Mareca Way => Mareca Way
# Brenda Way => Brenda Way
# Flagstaff Way => Flagstaff Way
# Woodfield Way => Woodfield Way
# Howard Way => Howard Way
# Missile Way => Missile Way
# Welland Way => Welland Way
# Astaire Way => Astaire Way
# Sandringham Way => Sandringham Way
# Westmeath Way => Westmeath Way
# Early Way => Early Way
# Lansdowne Way => Lansdowne Way
# Barbrook Way => Barbrook Way
# Cornwall Way => Cornwall Way
# Fuhrman Way => Fuhrman Way
# Paradise Way => Paradise Way
# Rezzano Way => Rezzano Way
# Camborne Way => Camborne Way
# Butterfield Way => Butterfield Way
# Cirby Way => Cirby Way
# Technology Way => Technology Way
# Canvasback Way => Canvasback Way
# Crawford Way => Crawford Way
# Castle Rock Way => Castle Rock Way
# Big Brook Way => Big Brook Way
# Wyman Way => Wyman Way
# Ice House Way => Ice House Way
# Shasta Way => Shasta Way
# Bolton Way => Bolton Way
# Grand Junction Way => Grand Junction Way
# Woodgate Way => Woodgate Way
# Ballantrae Way => Ballantrae Way
# Burwell Way => Burwell Way
# Buxton Way => Buxton Way
# Carpenter Way => Carpenter Way
# Majestic Prince Way => Majestic Prince Way
# Culverhill Way => Culverhill Way
# Sandhurst Way => Sandhurst Way
# Dallen Way => Dallen Way
# Point West Way => Point West Way
# Derby Way => Derby Way
# Blue Skies Way => Blue Skies Way
# Calverhall Way => Calverhall Way
# Hurlston Way => Hurlston Way
# Morning Mist Way => Morning Mist Way
# Diego Way => Diego Way
# Creamery Way => Creamery Way
# Serpa Way => Serpa Way
# Blakesley Way => Blakesley Way
# Zinfandel Dr. => Zinfandel Drive
# Fairway Dr. => Fairway Drive
# College Oak Dr. => College Oak Drive
# Sprockett Bikeway => Sprockett Bikeway
# Tribute Road, Suite E => Tribute Road Suite E
# Stageline Circle => Stageline Circle
# Meadowlark Circle => Meadowlark Circle
# Evergreen Circle => Evergreen Circle
# Camp Whitney Circle => Camp Whitney Circle
# Brookline Circle => Brookline Circle
# Cottage Circle => Cottage Circle
# Brennen Circle => Brennen Circle
# Windward Circle => Windward Circle
# Freeman Circle => Freeman Circle
# Hughes Circle => Hughes Circle
# McNair Circle => Mcnair Circle
# Caldarella Circle => Caldarella Circle
# San Lucas Circle => San Lucas Circle
# Flocchini Circle => Flocchini Circle
# Rockrose Circle => Rockrose Circle
# Daffodil Circle => Daffodil Circle
# Sorrell Circle => Sorrell Circle
# Grasmere Circle => Grasmere Circle
# Glastonbury Circle => Glastonbury Circle
# Mosswood Circle => Mosswood Circle
# Rogue River Circle => Rogue River Circle
# San Carlos Circle => San Carlos Circle
# Wighill Circle => Wighill Circle
# Grouse Run Circle => Grouse Run Circle
# Montclair Circle => Montclair Circle
# Dunsley Circle => Dunsley Circle
# Clearbrook Circle => Clearbrook Circle
# Pasatiempo Circle => Pasatiempo Circle
# Staxton Circle => Staxton Circle
# Anvil Circle => Anvil Circle
# Campfire Circle => Campfire Circle
# Corona Circle => Corona Circle
# Racetrack Circle => Racetrack Circle
# Imran Woods Circle => Imran Woods Circle
# Hartland Circle => Hartland Circle
# Gooseberry Circle => Gooseberry Circle
# Hilmerton Circle => Hilmerton Circle
# Ferndale Circle => Ferndale Circle
# Half Moon Bay Circle => Half Moon Bay Circle
# Kathy Circle => Kathy Circle
# Creekstone Circle => Creekstone Circle
# Dornie Circle => Dornie Circle
# Welton Circle => Welton Circle
# Bottlebrush Circle => Bottlebrush Circle
# Everley Circle => Everley Circle
# Pitzer Circle => Pitzer Circle
# Ridgemere Circle => Ridgemere Circle
# San Diego Circle => San Diego Circle
# Santiago Circle => Santiago Circle
# Saint Basil Circle => Saint Basil Circle
# Sterling Circle => Sterling Circle
# Brick Mason Circle => Brick Mason Circle
# Park Circle => Park Circle
# Huckleberry Circle => Huckleberry Circle
# Westwood Circle => Westwood Circle
# Terracina Circle => Terracina Circle
# Manza Circle => Manza Circle
# Orchard Park Circle => Orchard Park Circle
# Brookfield Circle => Brookfield Circle
# Deerwood Circle => Deerwood Circle
# Foxcroft Circle => Foxcroft Circle
# Las Brisas Circle => Las Brisas Circle
# Solano Park Circle => Solano Park Circle
# Abilene Circle => Abilene Circle
# California Circle => California Circle
# Snapdragon Circle => Snapdragon Circle
# Wild Plains Circle => Wild Plains Circle
# Tradewinds Circle => Tradewinds Circle
# Snowberry Circle => Snowberry Circle
# 9321 => 9321
# DESTINY DR => Destiny Drive
# HIGHLAND POINTE DR => Highland Pointe Drive
# Grass Valley Highway => Grass Valley Highway
# Lincoln Newcastle Highway => Lincoln Newcastle Highway
# Meadowlark Way & Maidu Dr Near Rocky Ridge => Meadowlark Way & Maidu Drive Near Rocky Ridge
# Freeport Blvd Uppr => Freeport Boulevard Uppr
# Penryn Rd Int Nw Of I-80 On Frontage Road (Boyington Road) => Penryn Road Intersection Northwest Of I-80 On Frontage Road (boyington Road)
# Alta Arden Expressway => Alta Arden Expressway
# PO Box 5259 => Po Box 5259
# College Park => College Park
# Russell Park => Russell Park
# Lake Washington Boulevar => Lake Washington Boulevar
# Southport P PKWY => Southport P Parkway
# California Highway 16, House No. 1 => California Highway 16 House No 1
# 2nd St/Rte 5 => 2nd St/rte 5
# Northgate => Northgate
# san lorenzo way => San Lorenzo Way
# 1050 Grass Valley Hwy => 1050 Grass Valley Highway
# Orchard Raod => Orchard Road
# North Quad => North Quad
# Oak Ave Pkwy => Oak Avenue Parkway
# Isles CT => Isles Court
# Via Ingoglia => Via Ingoglia
# Zollhaus => Zollhaus
# Arena => Arena
# County Road 18C => County Road 18c
# Auburn Ave. => Auburn Avenue
# Orange Grove Ave. => Orange Grove Avenue
# Norris Ave. => Norris Avenue
# Watt Ave. => Watt Avenue
# Cal Center => Cal Center
# Ne Side Next To Aquatic Center => Northeast Side Next To Aquatic Center
# Old Davis Road Extension => Old Davis Road Extension
# S Of Us 50, E Side Of Latrobe => S Of Us 50 E Side Of Latrobe
# Missionary Church Cirby & Orlando => Missionary Church Cirby & Orlando
# Sierra Gate Plaza => Sierra Gate Plaza
# Town Center Plaza => Town Center Plaza
# Douglas Blvd @ Buljan => Douglas Boulevard At Buljan
# Fair Oaks Boulevard, Fair Oaks, CA 95628-7416 => Fair Oaks Boulevard Fair Oaks Ca 95628-7416
# Arthur St => Arthur Street
# E Bidwell St => E Bidwell Street
# County Road 99 => County Road 99
# 13th Ave Rte 99 => 13th Avenue Rte 99
# 47th Avenue / Rte 99 => 47th Avenue / Rte 99
# Capitol Mall => Capitol Mall
# Physical Sciences Mall => Physical Sciences Mall
# Broadway => Broadway
# County Road 102 => County Road 102
# Across Street From Factory Outlet Stores => Across Street From Factory Outlet Stores
# Bridlewood => Bridlewood
# Sr 193 @ Lincoln / Ophir I/C => Sr 193 At Lincoln / Ophir I/c
# Horseshoe Bar Rd Int S Side => Horseshoe Bar Road Intersection S Side
# Elkhorn Blvd Sw Side => Elkhorn Boulevard Southwest Side
# Int Bell Rd & Bowman Rd Nw Side => Intersection Bell Road & Bowman Road Northwest Side
# 9311 => 9311
# Northgate Blvd. => Northgate Boulevard
# Arena Blvd. => Arena Boulevard
# Fair Oaks Blvd. => Fair Oaks Boulevard
# Auburn Blvd. => Auburn Boulevard
# Industrial => Industrial
# Via Riata => Via Riata
# Geneva Pt Dr @ Stockton => Geneva Point Drive At Stockton
# Devonport Loop => Devonport Loop
# Benton Loop => Benton Loop
# Rainhill Loop => Rainhill Loop
# Appersett Loop => Appersett Loop
# Warm Hearth Loop => Warm Hearth Loop
# Tapaderas Loop => Tapaderas Loop
# Pipestone Loop => Pipestone Loop
# Eskaton Loop => Eskaton Loop
# Bickleigh Loop => Bickleigh Loop
# Secret Lake Loop => Secret Lake Loop
# Land End Loop => Land End Loop
# Vignolia Loop => Vignolia Loop
# Penstone Loop => Penstone Loop
# Ellesmere Loop => Ellesmere Loop
# Whispering Creek Loop => Whispering Creek Loop
# Aurora Loop => Aurora Loop
# S Side Sierra College Blvd Int => S Side Sierra College Boulevard Intersection
# Ne Side Merrychase Drive Int => Northeast Side Merrychase Drive Intersection
# Indian Hills Road & Newcastle Rd Int => Indian Hills Road & Newcastle Road Intersection
# E Side Newcastle Rd Int => E Side Newcastle Road Intersection
# Se Cnr  Sheldon Rd Int => Southeast Corner  Sheldon Road Intersection
# Olive Dr => Olive Drive
# State University Dr => State University Drive
# Banfield Dr => Banfield Drive
# Promenade Circle #110, => Promenade Circle #110
# L ST => L Street
# 3rd St / Rte 50 => 3rd Street / Rte 50
# Del Paso Boulevard el Monte Avenue Alley => Del Paso Boulevard El Monte Avenue Alley
# Elkhorn PlaceZ => Elkhorn Plaza
# Town Center PlaceZ => Town Center Plaza
# East Roseville => East Roseville
# Simon Terrace => Simon Terrace
# Serrano Terrace => Serrano Terrace
# Messina Terrace => Messina Terrace
# Galleria Blvd => Galleria Boulevard
# N. Market Blvd => N Market Boulevard
# 9660 Stockton Blvd => 9660 Stockton Boulevard
# Folsom Blvd => Folsom Boulevard
# Stockton Blvd => Stockton Boulevard
# Mace Blvd => Mace Boulevard
# Arena Blvd => Arena Boulevard
# Auburn Blvd => Auburn Boulevard
# Russell Blvd => Russell Boulevard
# Northgate Blvd => Northgate Boulevard
# 6010 Folsom Blvd => 6010 Folsom Boulevard
# Franklin Blvd => Franklin Boulevard
# Norris Ave => Norris Avenue
# Central Ave => Central Avenue
# Pasadena Ave => Pasadena Avenue
# Ne Quad Enterprise Dr / I-80 Ic @ Capitol Ave => Northeast Quad Enterprise Drive / I-80 Ic At Capitol Avenue
# Manzanita Ave => Manzanita Avenue
# Auburn Ave => Auburn Avenue
# Sw Quad Enterprise Dr / I-80 Ic => Southwest Quad Enterprise Drive / I-80 Ic
# Auburn => Auburn

# %% [markdown]
# Problems Encountered:
# - One of the issues with this dataset is that the street names like S,N,W, and E share the naming conventions with streets that specify the geographical position (i.e., N=North, S=South, W=West, E=East). This makes it difficult to programatically decide how a street like "N Groove St." should be converted into "North Grove Street" withut changing the "N Street" into "North Street".
# - For the zip code, I found that postal code 96816 does not corespond to Sacramento region, but rather to Honolulu. I removed the entries if that postal code.
# - On a few occasions, I have cleaned the dataset for common misspellings.

# %%
#all that is left is to load the json file in MongoDB

# %%
import pymongo
import pprint

def get_db():
    from pymongo import MongoClient
    client = MongoClient('localhost:27017')
    db = client.openStreetMaps
    return db

db=get_db()



print "Number of documents is "+str(db.sacramento.find().count())
print "Number of nodes is "+str(db.sacramento.find({"type":"node"}).count())
print "Number of way nodes is "+str(db.sacramento.find({"type":"way"}).count())
print "Number of unique users is "+str(len(db.sacramento.distinct("user")))
# Out:
# Number of documents is 1129233
# Number of nodes is 1028822
# Number of way nodes is 100346
# Number of unique users is 982

# %%
#use list to access the result of the aggregation querry
#see http://stackoverflow.com/questions/30333020/mongodb-pymongo-aggregate-gives-strange-output-something-about-cursor
result=list(db.sacramento.aggregate([{"$group":{"_id":"$user","count":{"$sum":1}}},
                               {"$sort": {"count": -1}},{"$limit":5}] ))
pprint.pprint(result)
# Out:
# [{u'_id': u'T99', u'count': 203149},
#  {u'_id': u'woodpeck_fixbot', u'count': 194983},
#  {u'_id': u'jraller', u'count': 119323},
#  {u'_id': u'nmixter', u'count': 88989},
#  {u'_id': u'Eureka gold', u'count': 71309}]

# %%
#print most common 10 ammenities
result=list(db.sacramento.aggregate([
            {"$match":{"amenity":{"$exists":1}}}, #remove the ammenities with none fields
            {"$group":{"_id":"$amenity","count":{"$sum":1}}},
            {"$sort": {"count": -1}},
            {"$limit":10}
        ]))
pprint.pprint(result)
# Out:
# [{u'_id': u'parking', u'count': 1785},
#  {u'_id': u'post_box', u'count': 1478},
#  {u'_id': u'school', u'count': 814},
#  {u'_id': u'place_of_worship', u'count': 605},
#  {u'_id': u'restaurant', u'count': 409},
#  {u'_id': u'fast_food', u'count': 299},
#  {u'_id': u'fuel', u'count': 209},
#  {u'_id': u'cafe', u'count': 151},
#  {u'_id': u'bench', u'count': 139},
#  {u'_id': u'toilets', u'count': 122}]

# %%
result=list(db.sacramento.aggregate([
            {"$match":{"amenity":{"$exists":1}, "amenity":"toilets"}},
            {"$group":{"_id":{"User":"$user"},"count":{"$sum":1}}},
            {"$sort": {"count": -1}},
            {"$limit":10}
        ]))

pprint.pprint(result)
# Out:
# [{u'_id': {u'User': u'T99'}, u'count': 19},
#  {u'_id': {u'User': u'Charles_Smothers'}, u'count': 13},
#  {u'_id': {u'User': u'BK_man'}, u'count': 11},
#  {u'_id': {u'User': u'tjstansell'}, u'count': 10},
#  {u'_id': {u'User': u'Bryce C Nesbitt'}, u'count': 10},
#  {u'_id': {u'User': u'wallclimber21'}, u'count': 8},
#  {u'_id': {u'User': u'Adam Mazurkiewicz'}, u'count': 6},
#  {u'_id': {u'User': u'nmixter'}, u'count': 6},
#  {u'_id': {u'User': u'animeigo'}, u'count': 4},
#  {u'_id': {u'User': u'jraller'}, u'count': 4}]

# %%
#print top 5 denominations
result=list(db.sacramento.aggregate([
            {"$match":{"denomination":{"$exists":1}, "amenity":"place_of_worship"}}, #remove the denominations with none fields
            {"$group":{"_id":{"Denomination":"$denomination"},"count":{"$sum":1}}},
            {"$sort": {"count": -1}},
            {"$limit":5}
        ]))

pprint.pprint(result)
# Out:
# [{u'_id': {u'Denomination': u'baptist'}, u'count': 111},
#  {u'_id': {u'Denomination': u'lutheran'}, u'count': 37},
#  {u'_id': {u'Denomination': u'methodist'}, u'count': 35},
#  {u'_id': {u'Denomination': u'catholic'}, u'count': 35},
#  {u'_id': {u'Denomination': u'presbyterian'}, u'count': 21}]

# %%
#print top 5 religions
result=list(db.sacramento.aggregate([
            {"$match":{"religion":{"$exists":1}, "amenity":"place_of_worship"}}, #remove the religions with none fields
            {"$group":{"_id":{"Religion":"$religion"},"count":{"$sum":1}}},
            {"$sort": {"count": -1}},
            {"$limit":5}
        ]))

pprint.pprint(result)
# Out:
# [{u'_id': {u'Religion': u'christian'}, u'count': 560},
#  {u'_id': {u'Religion': u'buddhist'}, u'count': 5},
#  {u'_id': {u'Religion': u'muslim'}, u'count': 3},
#  {u'_id': {u'Religion': u'unitarian_universalist'}, u'count': 2},
#  {u'_id': {u'Religion': u'sikh'}, u'count': 2}]

# %%
#let's look at food stuff; Top 10 cuisines
result=list(db.sacramento.aggregate([
            {"$match":{"cuisine":{"$exists":1}}}, #remove the cuisines with none fields
            {"$group":{"_id":{"Food":"$cuisine"},"count":{"$sum":1}}},
            {"$sort": {"count": -1}},
            {"$limit":10}
        ]))

pprint.pprint(result)
# Out:
# [{u'_id': {u'Food': u'burger'}, u'count': 102},
#  {u'_id': {u'Food': u'mexican'}, u'count': 75},
#  {u'_id': {u'Food': u'coffee_shop'}, u'count': 61},
#  {u'_id': {u'Food': u'sandwich'}, u'count': 49},
#  {u'_id': {u'Food': u'pizza'}, u'count': 45},
#  {u'_id': {u'Food': u'american'}, u'count': 21},
#  {u'_id': {u'Food': u'chinese'}, u'count': 18},
#  {u'_id': {u'Food': u'chicken'}, u'count': 17},
#  {u'_id': {u'Food': u'italian'}, u'count': 16},
#  {u'_id': {u'Food': u'japanese'}, u'count': 10}]

# %%
#find number of fast_food
print "Number of way fast foods is "+str(db.sacramento.find({"amenity":"fast_food"}).count())
# Out:
# Number of way nodes is 299

# %%
#look at fast food
result=list(db.sacramento.aggregate([
            {"$match":{"cuisine":{"$exists":1}, "amenity":"fast_food"}}, #remove the ammenities with none fields
            {"$group":{"_id":{"Food":"$cuisine"},"count":{"$sum":1}}},
            {"$sort": {"count": -1}},
            {"$limit":10}
        ]))

pprint.pprint(result)
# Out:
# [{u'_id': {u'Food': u'burger'}, u'count': 81},
#  {u'_id': {u'Food': u'sandwich'}, u'count': 34},
#  {u'_id': {u'Food': u'mexican'}, u'count': 33},
#  {u'_id': {u'Food': u'pizza'}, u'count': 20},
#  {u'_id': {u'Food': u'chicken'}, u'count': 14},
#  {u'_id': {u'Food': u'chinese'}, u'count': 5},
#  {u'_id': {u'Food': u'ice_cream'}, u'count': 3},
#  {u'_id': {u'Food': u'japanese'}, u'count': 2},
#  {u'_id': {u'Food': u'asian'}, u'count': 2},
#  {u'_id': {u'Food': u'hotdog'}, u'count': 1}]

# %%
#names of popular fast food joints
#look at fast food
result=list(db.sacramento.aggregate([
            {"$match":{"name":{"$exists":1}, "amenity":"fast_food"}}, #remove the ammenities with none fields
            {"$group":{"_id":{"Name":"$name"},"count":{"$sum":1}}},
            {"$sort": {"count": -1}},
            {"$limit":10}
        ]))
pprint.pprint(result)
# Out:
# [{u'_id': {u'Name': u"McDonald's"}, u'count': 34},
#  {u'_id': {u'Name': u'Taco Bell'}, u'count': 26},
#  {u'_id': {u'Name': u'Subway'}, u'count': 22},
#  {u'_id': {u'Name': u'Burger King'}, u'count': 15},
#  {u'_id': {u'Name': u'KFC'}, u'count': 13},
#  {u'_id': {u'Name': u'Jack in the Box'}, u'count': 9},
#  {u'_id': {u'Name': u'A&W'}, u'count': 9},
#  {u'_id': {u'Name': u"Carl's Jr."}, u'count': 8},
#  {u'_id': {u'Name': u'Panda Express'}, u'count': 7},
#  {u'_id': {u'Name': u'Del Taco'}, u'count': 7}]

# %%
#look at popular shops
result=list(db.sacramento.aggregate([
            {"$match":{"shop":{"$exists":1}}}, #remove the ammenities with none fields
            {"$group":{"_id":{"Shop":"$shop"},"count":{"$sum":1}}},
            {"$sort": {"count": -1}},
            {"$limit":10}
        ]))
pprint.pprint(result)
# Out:
# [{u'_id': {u'Shop': u'supermarket'}, u'count': 120},
#  {u'_id': {u'Shop': u'car'}, u'count': 88},
#  {u'_id': {u'Shop': u'clothes'}, u'count': 59},
#  {u'_id': {u'Shop': u'convenience'}, u'count': 50},
#  {u'_id': {u'Shop': u'department_store'}, u'count': 35},
#  {u'_id': {u'Shop': u'hairdresser'}, u'count': 32},
#  {u'_id': {u'Shop': u'shoes'}, u'count': 26},
#  {u'_id': {u'Shop': u'beauty'}, u'count': 25},
#  {u'_id': {u'Shop': u'car_repair'}, u'count': 23},
#  {u'_id': {u'Shop': u'electronics'}, u'count': 22}]

# %%
#look at most popular shops
result=list(db.sacramento.aggregate([
            {"$match":{"shop":{"$exists":1}, "amenity":"shop"}}, #remove the ammenities with none fields
            {"$group":{"_id":{"Name":"$shop"},"count":{"$sum":1}}},
            {"$sort": {"count": -1}},
            {"$limit":10}
        ]))
pprint.pprint(result)
# Out:
# [{u'_id': {u'Name': u'clothes'}, u'count': 3},
#  {u'_id': {u'Name': u'baby_goods'}, u'count': 1},
#  {u'_id': {u'Name': u'beauty'}, u'count': 1},
#  {u'_id': {u'Name': u'shoes'}, u'count': 1},
#  {u'_id': {u'Name': u'car_repair'}, u'count': 1},
#  {u'_id': {u'Name': u'interior_decoration'}, u'count': 1},
#  {u'_id': {u'Name': u'alcohol'}, u'count': 1},
#  {u'_id': {u'Name': u'doityourself'}, u'count': 1}]
